# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting spacy
#   Downloading spacy-3.8.14-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.2 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (14 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.26.7-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.13/site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.13/site-packages (from spacy) (2.4.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.13/site-packages (from spacy) (2.33.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/lib/python3.13/site-packages (from spacy) (2.13.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.13/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.13/site-packages (from spacy) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.13/site-packages (from spacy) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /opt/conda/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.3)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.4.22)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.5 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading cloudpathlib-0.24.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open>=5.2.1 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading smart_open-7.6.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: httpx>=0.24.0 in /opt/conda/lib/python3.13/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.13/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.13/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.13/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting wrapt (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy)
#   Downloading wrapt-2.2.1-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.13/site-packages (from jinja2->spacy) (3.0.3)
# Downloading spacy-3.8.14-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (32.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 13.4 MB/s  0:00:02 eta 0:00:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (254 kB)
# Downloading murmurhash-1.0.15-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (133 kB)
# Downloading preshed-3.0.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (839 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 839.9/839.9 kB 9.1 MB/s  0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.1 MB/s  0:00:00
# Downloading thinc-8.3.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 13.7 MB/s  0:00:00 eta 0:00:01
# Downloading blis-1.3.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 15.6 MB/s  0:00:00eta 0:00:01
# Downloading typer-0.26.7-py3-none-any.whl (122 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading cloudpathlib-0.24.0-py3-none-any.whl (63 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading smart_open-7.6.1-py3-none-any.whl (64 kB)
# Downloading wrapt-2.2.1-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (167 kB)
# Installing collected packages: wrapt, wasabi, spacy-loggers, spacy-legacy, shellingham, murmurhash, mdurl, cymem, confection, cloudpathlib, catalogue, blis, annotated-doc, srsly, smart-open, preshed, markdown-it-py, thinc, rich, typer, weasel, spacy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22/22 [spacy]m21/22 [spacy]wn-it-py]
# Successfully installed annotated-doc-0.0.4 blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.24.0 confection-1.3.3 cymem-2.0.13 markdown-it-py-4.2.0 mdurl-0.1.2 murmurhash-1.0.15 preshed-3.0.13 rich-15.0.0 shellingham-1.5.4 smart-open-7.6.1 spacy-3.8.14 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 typer-0.26.7 wasabi-1.1.3 weasel-1.0.0 wrapt-2.2.1
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 10.8 MB/s  0:00:01m0:00:010:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import os
import sys
import re

# =========================================================
# 1. ÉP VERSION PYSPARK (PHẢI CHẠY ĐẦU TIÊN TRƯỚC KHI IMPORT)
# =========================================================
modules_to_remove = [mod for mod in sys.modules if mod.startswith('pyspark') or mod.startswith('py4j')]
for mod in modules_to_remove: 
    del sys.modules[mod]

sys.path = [p for p in sys.path if "/usr/local/spark" not in p]
if "PYTHONPATH" in os.environ: 
    del os.environ["PYTHONPATH"]
    
conda_site_packages = "/opt/conda/lib/python3.13/site-packages"
if conda_site_packages not in sys.path: 
    sys.path.insert(0, conda_site_packages)
    
os.environ["SPARK_HOME"] = os.path.join(conda_site_packages, "pyspark")
os.environ["PYSPARK_PYTHON"] = "python3"
os.environ["PYSPARK_DRIVER_PYTHON"] = "python3"


# =========================================================
# 2. BÂY GIỜ MỚI IMPORT PYSPARK VÀ KHỞI TẠO SESSION
# =========================================================
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_date

spark = SparkSession.builder \
    .appName("Lemmatization_Pipeline") \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.262,org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.5.0") \
    .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000") \
    .config("spark.hadoop.fs.s3a.access.key", "dataNLPmining-lab") \
    .config("spark.hadoop.fs.s3a.secret.key", "dataNLPmining-lab") \
    .config("spark.hadoop.fs.s3a.path.style.access", "true") \
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
    .config("spark.sql.catalog.my_catalog", "org.apache.iceberg.spark.SparkCatalog") \
    .config("spark.sql.catalog.my_catalog.type", "hadoop") \
    .config("spark.sql.catalog.my_catalog.warehouse", "s3a://raw-financial-data/iceberg_warehouse") \
    .getOrCreate()


# =========================================================
# 3. VÁ LỖI THỜI GIAN HADOOP
# =========================================================
hadoop_conf = spark._jsc.hadoopConfiguration()
iterator = hadoop_conf.iterator()
while iterator.hasNext():
    entry = iterator.next()
    val = str(entry.getValue()).strip().lower()
    match = re.fullmatch(r"(\d+)([smhd])", val)
    if match:
        num, unit = int(match.group(1)), match.group(2)
        ms_val = num * 1000 if unit == 's' else num * 60000 if unit == 'm' else num * 3600000 if unit == 'h' else num * 86400000
        hadoop_conf.set(entry.getKey(), str(ms_val))

print("✅ Khởi tạo Spark và môi trường hoàn tất!")
# Out:
# ✅ Khởi tạo Spark và môi trường hoàn tất!

# %%
import re
import spacy
from pyspark.sql.functions import col, udf
from pyspark.sql.types import ArrayType, StringType

nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

def extract_lemmas(text):
    if not text: return []
    text = re.sub(r'[^a-z\s]', ' ', str(text).lower())
    text = re.sub(r'\s+', ' ', text).strip()
    if not text: return []
    return [token.lemma_ for token in nlp(text) if not token.is_stop and len(token.text.strip()) > 1]

lemma_udf = udf(extract_lemmas, ArrayType(StringType()))

# Đọc dữ liệu từ Raw Zone
df_news = spark.read.table("my_catalog.raw_zone.news_data_clean")

# Xử lý Lemma
df_lemmas = df_news.select(
    col("id"),
    col("published_at"),
    lemma_udf(col("title")).alias("title_lemmas"),
    lemma_udf(col("summary")).alias("summary_lemmas")
)

# Lưu vào Processed Zone
spark.sql("CREATE NAMESPACE IF NOT EXISTS my_catalog.processed_zone")
df_lemmas.write.format("iceberg").mode("overwrite").saveAsTable("my_catalog.processed_zone.news_lemmas")
print("✅ Đã xử lý và lưu bảng Lemma thành công!")
# Out:
# ✅ Đã xử lý và lưu bảng Lemma thành công!
